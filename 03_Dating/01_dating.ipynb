# %% [markdown]
# # **CHAPTER 4. Bayesian analysis: dating**

# %% [markdown]
# First and foremost create a directory to store all the data

# %%
! mkdir data/

# %% [markdown]
# Launch `BEAUTi`

# %% [markdown]
# Upload:<br>
# 1. `NADH-quinone_oxidoreductase_subunit_M_trim.fa`
# 2. `Cytochrome_b_c1_trim.fa`
# 3. `ATP_synthase_subunit_a_trim.fa`

# %% [markdown]
# ![Screenshot 2025-02-09 at 12.20.52.png](<attachment:Screenshot 2025-02-09 at 12.20.52.png>)

# %% [markdown]
# Select `mtREV` substitution model

# %% [markdown]
# ![Screenshot 2025-02-09 at 12.21.01.png](<attachment:Screenshot 2025-02-09 at 12.21.01.png>)

# %% [markdown]
# Go to the `Priors`

# %% [markdown]
# ![Screenshot 2025-02-09 at 12.21.26.png](<attachment:Screenshot 2025-02-09 at 12.21.26.png>)

# %% [markdown]
# Set this setting for `clock.rate`

# %% [markdown]
# ![Screenshot 2025-02-09 at 12.21.22.png](<attachment:Screenshot 2025-02-09 at 12.21.22.png>)

# %% [markdown]
# Set `100000000` for `Length of chain`<br>
# And `10000` for `Log parameters every`

# %% [markdown]
# ![Screenshot 2025-02-09 at 12.24.17.png](<attachment:Screenshot 2025-02-09 at 12.24.17.png>)

# %% [markdown]
# Click `Generate BEAST File...`

# %% [markdown]
# Lanch `BEAST`

# %%
! beast data/dating_tree.xml

# %% [markdown]
# Now wait for 18.5 hours (valid for Mac Mini M4)

# %% [markdown]
# Mode all the files to `data/` directory

# %%
! mv dating_tree.* data/

# %% [markdown]
# Launch `Tracer`

# %% [markdown]
# Go to `Terminal` and write `tracer`. Upload there `data/dating_tree.log`. Evaluate the tree!

# %% [markdown]
# Launch `TreeAnnotator`

# %% [markdown]
# Use this parameters:

# %% [markdown]
# ![Screenshot 2025-02-09 at 12.27.25.png](<attachment:Screenshot 2025-02-09 at 12.27.25.png>)

# %% [markdown]
# Click `Run`

# %% [markdown]
# ![Screenshot 2025-02-09 at 12.27.41.png](<attachment:Screenshot 2025-02-09 at 12.27.41.png>)

# %% [markdown]
# Good job!

# %% [markdown]
# Now proceed to the `02_ggtree_journal.R` to visualize the dated tree!
